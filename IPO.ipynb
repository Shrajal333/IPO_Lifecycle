# %% [markdown]
# # Importing Libraries

# %%
from trading_engine import *

# %% [markdown]
# # Input Parameters

# %%
ma_type = "SMA" # Type of moving average
ma_period = 40 # Length of moving period
multiple_trades = True # True if we trade the same stock multiple times
randomizer_overall = 1 # Percent number of trades taken overall

initial_portfolio = 100 # Starting portfolio value
num_simulations = 5000 # Number of simulations for computing max drawdown
position_sizing = [10, 15, 20, 25] # Portfolio sizing

excel_file = "companies.xlsx"
end_date = "2024-12-31"
interval = "1wk"

# %% [markdown]
# # Loading Price Data

# %%
prices_dict = price_loader(ma_type, ma_period, excel_file, end_date, interval)
# Out:
# 100%|██████████| 92/92 [00:17<00:00,  5.21it/s]

# %% [markdown]
# # Trading Strategy

# %% [markdown]
# ### Hidden due to obvious reasons

# %% [markdown]
# # Metrics

# %%
metric_loader(trades, initial_portfolio, position_sizing, num_simulations, randomizer_overall)
# Out:
#                              Metric       Value
# 0                      Total Trades  243.000000
# 1                  Average Profit %   63.927557
# 2                    Average Loss %   -7.742126
# 3                      Max Profit %  259.309021
# 4                        Max Loss %  -19.098246
# 5              Average Holding days  127.771429
# 6   Average Holding Profitable days  290.379310
# 7       Average Holding Losing days   38.234177
# 8                       Trade Win %   34.979424
# 9                 Risk-Reward Ratio    8.257107
# 10                    Profit Factor    4.442114

# %%
metric_loader(trades_with_profit_booking, initial_portfolio, position_sizing, num_simulations, randomizer_overall)
# Out:
#                              Metric       Value
# 0                      Total Trades  244.000000
# 1                  Average Profit %   40.046843
# 2                    Average Loss %   -7.862272
# 3                      Max Profit %  300.308397
# 4                        Max Loss %  -19.098246
# 5              Average Holding days   79.889796
# 6   Average Holding Profitable days  152.932692
# 7       Average Holding Losing days   26.014184
# 8                       Trade Win %   42.213115
# 9                 Risk-Reward Ratio    5.093546
# 10                    Profit Factor    3.720817
